# %%
import sys
# !{sys.executable} -m pip install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Downloading https://files.pythonhosted.org/packages/1d/5d/3260694a59df0ec52f8b4883f5d23b130bc237602a1411fa670eae12351e/beautifulsoup4-4.7.1-py3-none-any.whl (94kB)
# Collecting soupsieve>=1.2 (from BeautifulSoup4)
#   Downloading https://files.pythonhosted.org/packages/bf/b3/2473abf05c4950c6a829ed5dcbc40d8b56d4351d15d6939c8ffb7c6b1a14/soupsieve-1.7.3-py2.py3-none-any.whl
# Installing collected packages: soupsieve, BeautifulSoup4
# Successfully installed BeautifulSoup4-4.7.1 soupsieve-1.7.3

# %%
import requests, re
from bs4 import BeautifulSoup

r = requests.get("https://www.century21.ca/search/Q-montreal/45.75035638507768;-74.1508183704102;45.36525235123009;-73.29800464970708/v_Gallery")

cont = r.content

soup = BeautifulSoup(cont,"html.parser")

allprice = soup.find_all("div",{"class":"list-price"})
allbeds = soup.find_all("div",{"class":"basic-stats"})

print(allprice)
print(allbeds)
# Out:
# [<div class="list-price"><a><span class="price">$6,500,000</span></a></div>, <div class="list-price"><a><span class="price">$4,495,000</span></a></div>, <div class="list-price"><a><span class="price">$3,500,000</span></a></div>, <div class="list-price"><a><span class="price">$2,850,000</span></a></div>, <div class="list-price"><a><span class="price">$2,188,000</span></a></div>, <div class="list-price"><a><span class="price">$1,790,000</span></a></div>, <div class="list-price"><a><span class="price">$1,700,000</span></a></div>, <div class="list-price"><a><span class="price">$1,700,000</span></a></div>, <div class="list-price"><a><span class="price">$1,395,000</span></a></div>, <div class="list-price"><a><span class="price">$1,380,000</span></a></div>, <div class="list-price"><a><span class="price">$1,198,000</span></a></div>, <div class="list-price"><a><span class="price">$1,099,000</span></a></div>, <div class="list-price"><a><span class="price">$1,095,000</span></a></div>, <div class="list-price"><a><span class="price">$1,075,000</span></a></div>, <div class="list-price"><a><span class="price">$1,000,000</span></a></div>, <div class="list-price"><a><span class="price">$1,000,000</span></a></div>, <div class="list-price"><a><span class="price">$999,900</span></a></div>, <div class="list-price"><a><span class="price">$998,000</span></a></div>, <div class="list-price"><a><span class="price">$995,000</span></a></div>, <div class="list-price"><a><span class="price">$950,000</span></a></div>, <div class="list-price"><a><span class="price">$928,000</span></a></div>, <div class="list-price"><a><span class="price">$899,000</span></a></div>, <div class="list-price"><a><span class="price">$899,000</span></a></div>, <div class="list-price"><a><span class="price">$878,000</span></a></div>, <div class="list-price"><a><span class="price">$850,000</span></a></div>, <div class="list-price"><a><span class="price">$839,000</span></a></div>, <div class="list-price"><a><span class="price">$819,000</span></a></div>, <div class="list-price"><a><span class="price">$799,000</span></a></div>, <div class="list-price"><a><span class="price">$775,000</span></a></div>, <div class="list-price"><a><span class="price">$754,900</span></a></div>, <div class="list-price"><a><span class="price">$749,900</span></a></div
baths</li></ul></div>, <div class="basic-stats"><ul><li class="beds">2 beds</li><li class="baths">2 baths</li><li class="sqft">1,396 living area</li></ul></div>, <div class="basic-stats"><ul><li class="beds">4 beds</li><li class="baths">2 baths</li><li class="sqft">1,801 living area</li></ul></div>, <div class="basic-stats"><ul><li class="beds">3 beds</li><li class="baths">2 baths</li></ul></div>, <div class="basic-stats"><ul><li class="beds">2 beds</li><li class="baths">1 bath</li></ul></div>, <div class="basic-stats"><ul><li class="beds">2 beds</li><li class="baths">1 bath</li><li class="sqft">3,950 living area</li></ul></div>, <div class="basic-stat ...

# %%
print(allprice[1].find("span",{"class":"price"}).text)
# Out:
# $89,900,000

# %%
l=[]

for item in allprice:
    d={}
    try:
        d["price"] = item.find("span",{"class":"price"}).text
    except:
        d["price"] = None
    l.append(d)
    
for item in allbeds:
    d={}
    try:
        d["beds"] = item.find("li",{"class":"beds"}).text
    except:
        d["beds"] = None
    l.append(d)

# %%
len(l)
# Out:
# 114

# %%
import pandas as pd
df = pd.DataFrame(l)
df
# Out:
#        beds       price
# 0       NaN  $6,500,000
# 1       NaN  $4,495,000
# 2       NaN  $3,500,000
# 3       NaN  $2,850,000
# 4       NaN  $2,188,000
# 5       NaN  $1,790,000
# 6       NaN  $1,700,000
# 7       NaN  $1,700,000
# 8       NaN  $1,395,000
# 9       NaN  $1,380,000
# 10      NaN  $1,198,000
# 11      NaN  $1,099,000
# 12      NaN  $1,095,000
# 13      NaN  $1,075,000
# 14      NaN  $1,000,000
# 15      NaN  $1,000,000
# 16      NaN    $999,900
# 17      NaN    $998,000
# 18      NaN    $995,000
# 19      NaN    $950,000
# 20      NaN    $928,000
# 21      NaN    $899,000
# 22      NaN    $899,000
# 23      NaN    $878,000
# 24      NaN    $850,000
# 25      NaN    $839,000
# 26      NaN    $819,000
# 27      NaN    $799,000
# 28      NaN    $775,000
# 29      NaN    $754,900
# ..      ...         ...
# 84   5 beds         NaN
# 85   3 beds         NaN
# 86   2 beds         NaN
# 87   4 beds         NaN
# 88   2 beds         NaN
# 89   4 beds         NaN
# 90   3 beds         NaN
# 91   2 beds         NaN
# 92   2 beds         NaN
# 93    1 bed         NaN
# 94   3 beds         NaN
# 95   2 beds         NaN
# 96   2 beds         NaN
# 97   4 beds         NaN
# 98   3 beds         NaN
# 99   2 beds         NaN
# 100  2 beds         NaN
# 101  3 beds         NaN
# 102  3 beds         NaN
# 103  3 beds         NaN
# 104  3 beds         NaN
# 105  2 beds         NaN
# 106  4 beds         NaN
# 107  3 beds         NaN
# 108  3 beds         NaN
# 109  5 beds         NaN
# 110  3 beds         NaN
# 111  4 beds         NaN
# 112  2 beds         NaN
# 113  2 beds         NaN
#
# [114 rows x 2 columns]
